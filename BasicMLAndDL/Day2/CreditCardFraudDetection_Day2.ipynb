# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
df=pd.read_csv("D:\\100MlChallenge\\Day2\\creditcard.csv")

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...         V21       V22       V23       V24  \
# ...

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
df.plot()
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c3d483a1c074> in <module>()
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
sns.heatmap(df.corr())

# %%
len(df)
# Out:
# 284807

# %%
fraud=df[df['Class']==1]
valid=df[df['Class']==0]
outlier=len(fraud)/len(df)
print("Outlier is {}".format(outlier))
print("fraud is {}".format(len(fraud)))
print("valid is {}".format(len(valid)))
# Out:
# Outlier is 0.001727485630620034
# fraud is 492
# valid is 284315

# %%
X_rand=df.iloc[60000:,:-1].values
Y_rand=df.iloc[60000:,30:31].values

# %%
X_rand.shape
# Out:
# (224807, 30)

# %%
data=df.sample(frac=0.2)

# %%
data.head(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184082  126084.0 -3.370473 -1.783564 -3.104888  1.596189  0.719623  0.855352
# 45001    42164.0 -3.868823 -2.188371  1.024966 -2.284207 -1.257460  0.575719
# 76633    56665.0 -2.078804 -1.437552  1.361680  1.470361  2.025015 -1.048764
# 54552    46500.0  0.926136 -2.198082  0.133436 -1.366116 -1.785524  0.068478
# 274496  166043.0  2.087402  0.255711 -2.701792  0.304663  0.867655 -1.537377
# 206676  136315.0 -0.738357  1.110605 -0.509382 -0.769359  1.059871  0.707803
# 168384  119202.0  2.071844 -0.980969 -1.355910 -0.992165 -0.563328 -0.800754
# 30418    35914.0  1.067379  0.040536  0.784279  1.213379 -0.413509  0.129499
# 48789    43785.0  1.270910 -0.547260  0.127520 -0.505710 -0.956324 -0.693135
# 102832   68386.0  1.108130  0.087081  0.503267  1.401809 -0.469648 -0.460578
#
#               V7        V8        V9  ...         V21       V22       V23  \
# ...

# %%
fraud=data[data['Class']==1]
valid=data[data['Class']==0]
outlier=len(fraud)/len(df)
print("Outlier is {}".format(outlier))
print("fraud is {}".format(len(fraud)))
print("valid is {}".format(len(valid)))
# Out:
# Outlier is 0.00027738082280281035
# fraud is 79
# valid is 56882

# %%
columns=[c for c in data.columns.tolist() if c not in ['Class']]
target='Class'
X=data[columns]
Y=data[target]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (56961, 30)
# (56961,)

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import LocalOutlierFactor

# %%
state=1
classifier_pipeline={'IsolationForest':IsolationForest(max_samples=len(X),contamination=outlier,random_state=state),
                     'LocalOutlierFactor':LocalOutlierFactor(n_neighbors=20,contamination=outlier)
                    }

# %%
for i,(clf_name,clf) in enumerate(classifier_pipeline.items()):
    if clf_name=='IsolationForest':
        clf.fit(X)
        y_pred=clf.predict(X)
        n_errors1=(y_pred!=Y).sum()
        print("Isolation Forest error {}".format(n_errors1))
        
    if clf_name=='LocalOutlierFactor':
        clf.fit_predict(X)
        score_pred=clf.negative_outlier_factor_
# Out:
# Isolation Forest error 56888

# %%
print("Isolation Forest")
print(classification_report(y_pred,Y))
# Out:
# Isolation Forest
#              precision    recall  f1-score   support
#
#          -1       0.00      0.00      0.00        16
#           0       0.00      0.00      0.00         0
#           1       0.92      0.00      0.00     56945
#
# avg / total       0.92      0.00      0.00     56961
# B:\Users\adity\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# B:\Users\adity\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
